# %% [markdown]
# <a href="https://colab.research.google.com/github/ankokovin/MyMLNotebooks/blob/master/MLGroupProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Прогнозирование количества преступлений в месяц в городе Чикаго
# Состав команды:
# - Коковин Алексей
# - Кокоулина Мария

# %% [markdown]
# ## Вопросы

# %% [markdown]
# ### Вопрос 1
# **Название проекта **
#
# Прогнозирование количества преступности в районах Чикаго.

# %% [markdown]
# ### Вопрос 4
# **Реальная проблема, которую собираетесь решать. Должно быть ОДНО короткое предложение.**
#
#  *Учтите, что формулировка проблемы должна быть такой, чтобы в результате выполнения проекта было
# понятно насколько вы справились с данной проблемой.*
#
# *Пример плохих проблем:
# •	Нужно просементировать пользователей
# •	Нужно проанализировать данные
# В реальной жизни такого не бывают. В реальной жизни бывают клиенты, которыем нужно отправлять
# промо. И тогда проблемой может быть определение того какому клиенту нужно отправить промо для
# достижения каких-то целей. Или какое воздействие является наиболее эффективным с точки зрения
# чего-то. *
#
# Необходимо выявить районы, где скорее всего произойдет большое количество
# преступлений, для того чтобы направить как можно больше усилий (патрулей) для
# их предотвращения.

# %% [markdown]
# ### Вопрос 5
# **Пояснение к проблеме. **
#
# *Почему считаете, что проблема реальна? Почему её нужно решать? В чём польза от её решения?*
#
# В настоящее время Чикаго является городом с  количеством преступности *заметно выше среднего*.[Source](https://en.wikipedia.org/wiki/Crime_in_Chicago)
#
# Необходимо наиболее продуктивно распределять ресурсы полиции, чтобы снизить число преступлений.

# %% [markdown]
# ### Вопрос 6
# **Пояснение о соответствии задачи анализа данных и обозначенной проблемы**
#
# Создаваемая модель позволит выявлять прогнозировать количество преступлений на территории города по районам, что позволит правильно распределять ресурсы полиции. Кроме того, данную модель в дальнейшем можно будет обучить и использовать для других городов.

# %% [markdown]
# ### Вопрос 7
# **Откуда получается выборка данных?**
#
# *Например, ссылка на выборку данных, или ссылка на сайт, где данные собирались, или указание,
# о других источниках данных. *
#
# Данные собирались с сайта https://data.cityofchicago.org и https://census.gov из нескольких таблиц:
#
# 1. [Crimes - 2001 to present](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present-Dashboard/5cd6-ry5g)
# 2. [Building Permits](https://data.cityofchicago.org/Buildings/Building-Permits/ydr8-5enu)
# 3. [Vacant and Abandoned Buildings - Violations](https://data.cityofchicago.org/Buildings/Vacant-and-Abandoned-Buildings-Violations/kc9i-wq85)
# 4. [Business Licenses](https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr)
# 5. [Building Violations](https://data.cityofchicago.org/Buildings/Building-Violations/22u3-xenr)
# 6. [311 Service Requests](https://data.cityofchicago.org/Service-Requests/311-Service-Requests/v6vf-nfxy)
# 7. [Public Health Statistics- Selected public health indicators by Chicago community area](https://data.cityofchicago.org/Health-Human-Services/Public-Health-Statistics-Selected-public-health-in/iqnk-2tcu)
# 8. [Survey of income and program participation (SIPP)](https://www.census.gov/programs-surveys/sipp.html)

# %% [markdown]
# ### Вопрос 8
# **Постановка задачи анализа данных и/или машинного обучения. ОДНО КОРОТКОЕ предложение.**
#
# *Пояснение: какая задача машинного обучения будет решаться, чтобы решить/помочь в решениии
# реальной проблемы. Если уместно указать, какая (какие) характеристики предсказываются по каким
# (без деталей). Например, построение модели, предсказывающей цену квартир по их характеристикам
# таким как площадь или количество комнат (Подробности оипшите позже).*
#
# Решаемая задача является задачей **регресии** - по текущему положению дел в городе предсказываются количества преступлений для каждого района.
#
# (Создаваемая модель позволит выявлять прогнозировать количество преступлений на территории города по районам в соответствии с историческими данными, а также такими факторами, как уровень безработицы, зарплаты, незаконных построек и другими.)

# %% [markdown]
# ### Вопрос 9
# **Что соответсвует одной строке выборки данных на которой решается задача анализа данных? ОДНА ФРАЗА**
#
# *Если совпадает с сырой выборкой данных указать: "совпадает".*
#
# *Например, для объявлений с Авито о квартирах, выборка данных будет совпадать с сырой выборкой
# данных. Если же мы рассматриваем случай анализа покупки товавров, то в одной строке вместо
# записи об одном купленом товаре, может быть информация обо всех купленных товарах в одном
# чеке, либо описание покупательского поведения одного человека.*
#
# Сырая выборка берется из нескольких таблиц: докладов о преступлениях, незаконных постройках, бизнесах в Чикаго. В результате одной строке данных будет соответствовать положение дел в городе на текущий месяц.

# %% [markdown]
# ### Вопрос 10
# **Информация об доступной информации по каждой строке финальной выборки данных**
#
# *Если совпадает с сырой выборкой данных указать: "совпадает".*
#
# *Например, для объявлений с Авито о квартирах, выборка данных будет совпадать с сырой выборкой
# данных. Если же мы рассматриваем случай анализа покупок товавров, то в одной строке вместо записи
# об одном купленом товаре и его характеристик (название, цена, количество купленных товаров), может
# быть информация обо всех купленных товарах в одном чеке, либо описание покупательского поведения
# одного человека (как давно человек был, средний чек, как часто ходил и прочее).*
#
# Сырая выборка содержит в себе информацию о всех конкретных преступлениях, в финальную выборку попадёт агрегированное значение - количество преступлений для данного района.

# %% [markdown]
# ### Вопрос 11
# **Информация об доступной информации по каждой таблице сырой выборки данных**
#
# *Например, по каждой квартире известны её цена продаже, количество комнат, общая площадь и т.д.*
#
# Пока хз

# %% [markdown]
# ### Вопрос 12
# **Что соответсвует одной строке полученной выборки данных? ОДНА ФРАЗА**
#
# *Например, одно объявление с Авито о продажи квартиры или запись об одном купленом товаре
# конкретным человеком в конкретный момент времени.*
#
# Состояние одного района города на момент начала месяца по всем перечисленным выше показателям.

# %% [markdown]
# ###Вопрос 13
# **Краткий план работы над проектом**
#
# 1.	Собрать данные из всех таблиц.
# 2.	Соединить данные в одну таблицу – сырую выборку.
# 3.	Провести подготовку данных.
# 4.	Проанализировать корреляцию данных, выбрать значимые признаки, составить  финальную выборку.
# 5. Разделить выборку на обучающую и тестовую.
# 6.	Выбрать одну или несколько моделей.
# 7.	Реализовать модели.
# 8.	Проверить модели на тестовой выборке.
# 9.	Выбрать наилучшую модель.
# 10.	Выполнить интеграцию модели.

# %% [markdown]
# ## Получение информации
#
# Большинство информации, используемой в работе, находится в свободном доступе на [сайте Chicago data portal](https://data.cityofchicago.org)

# %% [markdown]
# ###Информация о преступлениях
#
# [Crimes - 2001 to present](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present-Dashboard/5cd6-ry5g)
#
# если будем использовать API (*я планирую просто скачать всю базу, но я пока что с мобильного*, а API - для обновления и тестирования)

# %%
#!pip install sodapy
import pandas as pd
from sodapy import Socrata

#TO DO: crimes_df = pd.DataFrame.from_csv("Crimes_-_2001_to_present.csv")

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
crimes = client.get("6zsd-86xi", limit=2000)

# Convert to pandas DataFrame
crimes_df = pd.DataFrame.from_records(crimes)
crimes_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                           1                       21569
# 1                           9                        4301
# 2                           4                       22260
# 3                          46                       21572
# 4                           9                       21559
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                          29                         146
# 1                          12                         163
# 2                          53                         404
# 3                          41                         584
# 4                          12                         166
#
#   :@computed_region_d3ds_rm58 :@computed_region_d9mm_jgwp  \
# 0                         160                          21
# ...

# %% [markdown]
# Покажем на карте полученные точки. Для удобства также возьмём [границы города](https://dev.socrata.com/foundry/data.cityofchicago.org/qqq8-j68g)

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
city = client.get("qqq8-j68g", limit=2000)

# Convert to pandas DataFrame
city_MultyPoligon = pd.DataFrame.from_records(city)['the_geom'][0]['coordinates']
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
list(crimes_df)
crimes_df_located = crimes_df[pd.notnull(crimes_df['longitude'])]
crimes_df_located['longitude'][0]
# Out:
# '-87.70502856'

# %%
#!apt-get install libgeos-3.5.0
#!apt-get install libgeos-dev
#!pip install https://github.com/matplotlib/basemap/archive/master.zip
#!pip install pyproj==1.9.6
from mpl_toolkits.basemap import Basemap
from matplotlib import pyplot as plt
def map_of_chicago():
  fig = plt.figure(figsize=(8, 8))
  m = Basemap(projection='lcc', resolution='h', 
            lat_0=41.8, lon_0=-87.7,
            width=5E4, height=5.5E4)
  m.shadedrelief()
  m.drawcoastlines(color='gray')
  m.drawcountries(color='gray')
  m.drawstates(color='gray')

  for poly in city_MultyPoligon:
    for lines in poly:
      m.plot([float(x[0]) for x in lines],
          [float(x[1]) for x in lines],
           'g--',
           latlon=True)
  return m     

map_of_chicago().scatter(list(crimes_df_located['longitude'].astype(float)),
          list(crimes_df_located['latitude'].astype(float)),
         latlon=True)

# %% [markdown]
# ### Данные о разрешениях на постройку
# стоимость зданий может коррелировать с количеством преступлений
#
# [Building Permits](https://data.cityofchicago.org/Buildings/Building-Permits/ydr8-5enu)

# %%
#TO DO: permits_df = pd.DataFrame.from_csv("BuildingPermits.csv")

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
permits = client.get("9pkb-4fbf", limit=2000)

# Convert to pandas DataFrame
permits_df = pd.DataFrame.from_records(permits)
permits_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                         NaN                         NaN
# 1                          46                       14917
# 2                          16                        4451
# 3                           6                       22268
# 4                          40                       21538
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                         NaN                         NaN
# 1                          41                          63
# 2                          40                         539
# 3                          35                          86
# 4                          16                         647
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k _amount_paid  \
# 0                         NaN                         NaN         1680
# ...

# %%
permits_df_located = permits_df[pd.notnull(permits_df['longitude'])]

map_of_chicago().scatter(list(permits_df_located['longitude'].astype(float)),
          list(permits_df_located['latitude'].astype(float)),
         latlon=True)

# %% [markdown]
# ### Информация о пустующих зданиях
# [Vacant and Abandoned Buildings - Violations](https://data.cityofchicago.org/Buildings/Vacant-and-Abandoned-Buildings-Violations/kc9i-wq85)

# %%
from google.colab import drive
drive.mount('/content/drive')
vacant_violations = pd.DataFrame.from_csv('/content/drive/My Drive/Colab Notebooks/MLGroupProject/Vacant_and_Abandoned_Buildings_-_Violations.csv')
vacant_violations.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Violation Number Issued Date Issuing Department  \
# Docket Number
# 11BS01063A          11DR279704  01/24/2011            BLDINGS
# 11BS02904A          11DR286648  03/31/2011            BLDINGS
# 11BS04331A          11N0295731  05/28/2011            BLDINGS
# 11BS04331A          11N0295731  05/28/2011            BLDINGS
# 11BS04362A          11WO295906  06/01/2011            BLDINGS
#
#                     Last Hearing Date Property Address  \
# Docket Number
# ...

# %%
#Problem: no coordinates, just address
#vacant_violations_located = vacant_violations[pd.notnull(vacant_violations['longitude'])]

#map_of_chicago().scatter(list(vacant_violations_located['longitude'].astype(float)),
#          list(vacant_violations_located['latitude'].astype(float)),
#         latlon=True)

# %% [markdown]
# ### Информация о лицензиях на бизнес
#
# [Business Licenses](https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr)

# %%
#TO DO: businesses_df = pd.DataFrame.from_csv("BuildingPermits.csv")

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
businesses = client.get("r5kz-chrr", limit=2000)

# Convert to pandas DataFrame
businesses_df = pd.DataFrame.from_records(businesses)
businesses_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   account_number                       address application_created_date  \
# 0          51755  11243  CHESAPEAKE PLAC   1ST                      NaN
# 1          51944          5410  NEWPORT DR  40                      NaN
# 2          52896      17021 S MAGNOLIA DR  1ST                      NaN
# 3          54389         450  SKOKIE BLVD  904                      NaN
# 4          55668           261 N WEST AVE  1ST                      NaN
#
#   application_requirements_complete application_type             city  \
# 0               2000-06-16T00:00:00            RENEW      WESTCHESTER
# 1               2000-06-20T00:00:00            ISSUE  ROLLING MEADOWS
# 2               2000-06-20T00:00:00            ISSUE      HAZEL CREST
# 3               2000-06-20T00:00:00            ISSUE       NORTHBROOK
# 4               2000-06-20T00:00:00            ISSUE         ELMHURST
#
# ...

# %%
#Problem: no coordinates

#businesses_df_located = businesses_df[pd.notnull(businesses_df['longitude'])]

#map_of_chicago().scatter(list(businesses_df_located['longitude'].astype(float)),
#          list(businesses_df_located['latitude'].astype(float)),
#         latlon=True)

# %% [markdown]
# ### Информация о нарушениях правил постройки
# [Building Violations](https://data.cityofchicago.org/Buildings/Building-Violations/22u3-xenr)

# %%
#TO DO: businesses_df = pd.DataFrame.from_csv("BuildingPermits.csv")

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
build_violations = client.get("ucdv-yd74", limit=2000)

# Convert to pandas DataFrame
build_violations_df = pd.DataFrame.from_records(build_violations)
build_violations_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                           3                       22257
# 1                           3                       22257
# 2                          43                       21546
# 3                          43                       21546
# 4                          33                       21192
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                          44                         345
# 1                          44                         345
# 2                          31                         567
# 3                          31                         567
# 4                           1                         441
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  \
# 0                          23                          65
# ...

# %%
build_violations_df_located = build_violations_df[pd.notnull(build_violations_df['longitude'])]

map_of_chicago().scatter(list(build_violations_df_located['longitude'].astype(float)),
          list(build_violations_df_located['latitude'].astype(float)),
         latlon=True)

# %% [markdown]
# ### Вызовы службы 311
# [311 Service Requests](https://data.cityofchicago.org/Service-Requests/311-Service-Requests/v6vf-nfxy)

# %%
#TO DO: businesses_df = pd.DataFrame.from_csv("BuildingPermits.csv")

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
T_O_O = client.get("ucdv-yd74", limit=2000)

# Convert to pandas DataFrame
T_O_O_df = pd.DataFrame.from_records(T_O_O)
T_O_O_df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                           3                       22257
# 1                           3                       22257
# 2                          43                       21546
# 3                          43                       21546
# 4                          33                       21192
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                          44                         345
# 1                          44                         345
# 2                          31                         567
# 3                          31                         567
# 4                           1                         441
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  \
# 0                          23                          65
# ...

# %%
T_O_O_df_located = T_O_O_df[pd.notnull(T_O_O_df['longitude'])]

map_of_chicago().scatter(list(T_O_O_df_located['longitude'].astype(float)),
          list(T_O_O_df_located['latitude'].astype(float)),
         latlon=True)

# %% [markdown]
# #### Здесь стоит рассмотреть интересные типы вызовов

# %% [markdown]
# ### Информация о здравоохранении
# [Public Health Statistics- Selected public health indicators by Chicago community area](https://data.cityofchicago.org/Health-Human-Services/Public-Health-Statistics-Selected-public-health-in/iqnk-2tcu)

# %%
#TO DO

# %% [markdown]
# ### Информация зарплатах
# [Survey of income and program participation (SIPP)](https://www.census.gov/programs-surveys/sipp.html)

# %%
#TO DO - it's hard and i need vpn
